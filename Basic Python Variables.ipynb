# %%
def sumN(n):
    return n*(n+1)/2

# %%
import glob

# %%
glob.glob('Python Collection/retail_db/**')
# Out:
# ['Python Collection/retail_db\\categories',
#  'Python Collection/retail_db\\create_db.sql',
#  'Python Collection/retail_db\\create_db_tables_pg.sql',
#  'Python Collection/retail_db\\customers',
#  'Python Collection/retail_db\\departments',
#  'Python Collection/retail_db\\load_db_tables_pg.sql',
#  'Python Collection/retail_db\\orders',
#  'Python Collection/retail_db\\order_items',
#  'Python Collection/retail_db\\products',
#  'Python Collection/retail_db\\README.md',
#  'Python Collection/retail_db\\schemas.json']

# %%
import json

# %%
file=src_file_name[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 file=src_file_name[0]
#
# NameError: name 'src_file_name' is not defined

# %%
n=10
sumN(n)
# Out:
# 55.0

# %%
orders_file=open(r'Python Collection\retail_db\orders\part-00000')

# %%
orders_str=orders_file.read()

# %%
len(orders_str.splitlines())
# Out:
# 68883

# %%
orders=orders_str.splitlines()

# %%
len(orders)
# Out:
# 68883

# %%
orders[:20]
# Out:
# ['1,2013-07-25 00:00:00.0,11599,CLOSED',
#  '2,2013-07-25 00:00:00.0,256,PENDING_PAYMENT',
#  '3,2013-07-25 00:00:00.0,12111,COMPLETE',
#  '4,2013-07-25 00:00:00.0,8827,CLOSED',
#  '5,2013-07-25 00:00:00.0,11318,COMPLETE',
#  '6,2013-07-25 00:00:00.0,7130,COMPLETE',
#  '7,2013-07-25 00:00:00.0,4530,COMPLETE',
#  '8,2013-07-25 00:00:00.0,2911,PROCESSING',
#  '9,2013-07-25 00:00:00.0,5657,PENDING_PAYMENT',
#  '10,2013-07-25 00:00:00.0,5648,PENDING_PAYMENT',
#  '11,2013-07-25 00:00:00.0,918,PAYMENT_REVIEW',
#  '12,2013-07-25 00:00:00.0,1837,CLOSED',
#  '13,2013-07-25 00:00:00.0,9149,PENDING_PAYMENT',
#  '14,2013-07-25 00:00:00.0,9842,PROCESSING',
#  '15,2013-07-25 00:00:00.0,2568,COMPLETE',
#  '16,2013-07-25 00:00:00.0,7276,PENDING_PAYMENT',
#  '17,2013-07-25 00:00:00.0,2667,COMPLETE',
#  '18,2013-07-25 00:00:00.0,1205,CLOSED',
#  '19,2013-07-25 00:00:00.0,9488,PENDING_PAYMENT',
#  '20,2013-07-25 00:00:00.0,9198,PROCESSING']

# %%
def sumN(n):
    return n*(n+1)/2

# %%
l=[1,2,3,4,5,6,7]

# %%
[sumN(n) for n in l]
# Out:
# [1.0, 3.0, 6.0, 10.0, 15.0, 21.0, 28.0]

# %%
lambda n:(n*(n+1))/2
# Out:
# <function __main__.<lambda>(n)>

# %%
suml=lambda n:(n*(n+1))/2

# %%
suml(10)
# Out:
# 55.0

# %%
list(map(suml,l))
# Out:
# [1.0, 3.0, 6.0, 10.0, 15.0, 21.0, 28.0]

# %%
orders
# Out:
# ['1,2013-07-25 00:00:00.0,11599,CLOSED',
#  '2,2013-07-25 00:00:00.0,256,PENDING_PAYMENT',
#  '3,2013-07-25 00:00:00.0,12111,COMPLETE',
#  '4,2013-07-25 00:00:00.0,8827,CLOSED',
#  '5,2013-07-25 00:00:00.0,11318,COMPLETE',
#  '6,2013-07-25 00:00:00.0,7130,COMPLETE',
#  '7,2013-07-25 00:00:00.0,4530,COMPLETE',
#  '8,2013-07-25 00:00:00.0,2911,PROCESSING',
#  '9,2013-07-25 00:00:00.0,5657,PENDING_PAYMENT',
#  '10,2013-07-25 00:00:00.0,5648,PENDING_PAYMENT',
#  '11,2013-07-25 00:00:00.0,918,PAYMENT_REVIEW',
#  '12,2013-07-25 00:00:00.0,1837,CLOSED',
#  '13,2013-07-25 00:00:00.0,9149,PENDING_PAYMENT',
#  '14,2013-07-25 00:00:00.0,9842,PROCESSING',
#  '15,2013-07-25 00:00:00.0,2568,COMPLETE',
#  '16,2013-07-25 00:00:00.0,7276,PENDING_PAYMENT',
#  '17,2013-07-25 00:00:00.0,2667,COMPLETE',
#  '18,2013-07-25 00:00:00.0,1205,CLOSED',
#  '19,2013-07-25 00:00:00.0,9488,PENDING_PAYMENT',
#  '20,2013-07-25 00:00:00.0,9198,PROCESSING',
#  '21,2013-07-25 00:00:00.0,2711,PENDING',
# ...

# %%
order=orders[0]

# %%
order
# Out:
# '1,2013-07-25 00:00:00.0,11599,CLOSED'

# %%
order.split(",")
# Out:
# ['1', '2013-07-25 00:00:00.0', '11599', 'CLOSED']

# %%
orders
# Out:
# ['1,2013-07-25 00:00:00.0,11599,CLOSED',
#  '2,2013-07-25 00:00:00.0,256,PENDING_PAYMENT',
#  '3,2013-07-25 00:00:00.0,12111,COMPLETE',
#  '4,2013-07-25 00:00:00.0,8827,CLOSED',
#  '5,2013-07-25 00:00:00.0,11318,COMPLETE',
#  '6,2013-07-25 00:00:00.0,7130,COMPLETE',
#  '7,2013-07-25 00:00:00.0,4530,COMPLETE',
#  '8,2013-07-25 00:00:00.0,2911,PROCESSING',
#  '9,2013-07-25 00:00:00.0,5657,PENDING_PAYMENT',
#  '10,2013-07-25 00:00:00.0,5648,PENDING_PAYMENT',
#  '11,2013-07-25 00:00:00.0,918,PAYMENT_REVIEW',
#  '12,2013-07-25 00:00:00.0,1837,CLOSED',
#  '13,2013-07-25 00:00:00.0,9149,PENDING_PAYMENT',
#  '14,2013-07-25 00:00:00.0,9842,PROCESSING',
#  '15,2013-07-25 00:00:00.0,2568,COMPLETE',
#  '16,2013-07-25 00:00:00.0,7276,PENDING_PAYMENT',
#  '17,2013-07-25 00:00:00.0,2667,COMPLETE',
#  '18,2013-07-25 00:00:00.0,1205,CLOSED',
#  '19,2013-07-25 00:00:00.0,9488,PENDING_PAYMENT',
#  '20,2013-07-25 00:00:00.0,9198,PROCESSING',
#  '21,2013-07-25 00:00:00.0,2711,PENDING',
# ...

# %%
int(order.split(',')[2])
# Out:
# 11599

# %%
sorted(orders,key=lambda order: int(order.split(',')[2]),reverse=True)
# Out:
# ['41643,2014-04-08 00:00:00.0,12435,PENDING',
#  '61629,2013-12-21 00:00:00.0,12435,CANCELED',
#  '1868,2013-08-03 00:00:00.0,12434,CLOSED',
#  '4799,2013-08-23 00:00:00.0,12434,PENDING_PAYMENT',
#  '5303,2013-08-26 00:00:00.0,12434,PENDING',
#  '6160,2013-09-02 00:00:00.0,12434,COMPLETE',
#  '13544,2013-10-16 00:00:00.0,12434,PENDING',
#  '42915,2014-04-16 00:00:00.0,12434,COMPLETE',
#  '51800,2014-06-14 00:00:00.0,12434,ON_HOLD',
#  '61777,2013-12-26 00:00:00.0,12434,COMPLETE',
#  '15703,2013-11-02 00:00:00.0,12433,COMPLETE',
#  '42724,2014-04-15 00:00:00.0,12433,PENDING',
#  '58917,2013-09-07 00:00:00.0,12433,PAYMENT_REVIEW',
#  '65117,2014-05-01 00:00:00.0,12433,ON_HOLD',
#  '17889,2013-11-13 00:00:00.0,12432,PENDING_PAYMENT',
#  '17973,2013-11-13 00:00:00.0,12432,PENDING',
#  '29787,2014-01-25 00:00:00.0,12432,PENDING_PAYMENT',
#  '37846,2014-03-15 00:00:00.0,12432,COMPLETE',
#  '44064,2014-04-24 00:00:00.0,12432,COMPLETE',
#  '49279,2014-05-28 00:00:00.0,12432,COMPLETE',
# ...

# %%
import json

order_jd="{\order_id:1,order_date:'2013-07-25 00:00:00.0'}"
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\o'
# <>:3: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\vipul\AppData\Local\Temp\ipykernel_1296\2450115098.py:3: SyntaxWarning: invalid escape sequence '\o'
#   order_jd="{\order_id:1,order_date:'2013-07-25 00:00:00.0'}"

# %%
import json

order_jd = '{"id": 101, "name": "John", "product": "Apple", "status": "COMPLETE"}'

order = json.loads(order_jd)  # Converts JSON string to a Python dictionary
print(order)
  # Accessing values from the dictionary
# Out:
# {'id': 101, 'name': 'John', 'product': 'Apple', 'status': 'COMPLETE'}

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
print(pd.__version__)  # Should print the installed pandas version
# Out:
# 2.2.3

# %%
import os
print(os.listdir())  # Check for any 'pandas.py' file
# Out:
# ['.git', 'Basic Python Variables.ipynb', 'pr-venv', 'Project 1-File Format Converter.ipynb', 'Python Collection']

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
orders_coloumns=['order_id',
                 'order_date',
                 'order_customer_id',
                 'order_status']

# %%
orders=pd.read_csv(r'Python Collection\retail_db\orders\part-00000',names=orders_coloumns)

# %%
orders
# Out:
#        order_id             order_date  order_customer_id     order_status
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
 orders['order_status'].unique()
# Out:
# array(['CLOSED', 'PENDING_PAYMENT', 'COMPLETE', 'PROCESSING',
#        'PAYMENT_REVIEW', 'PENDING', 'ON_HOLD', 'CANCELED',
#        'SUSPECTED_FRAUD'], dtype=object)

# %%
orders.query('order_status == ("COMPLETE","CLOSED")')
# Out:
#        order_id             order_date  order_customer_id order_status
# 0             1  2013-07-25 00:00:00.0              11599       CLOSED
# 2             3  2013-07-25 00:00:00.0              12111     COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827       CLOSED
# 4             5  2013-07-25 00:00:00.0              11318     COMPLETE
# 5             6  2013-07-25 00:00:00.0               7130     COMPLETE
# ...         ...                    ...                ...          ...
# 68875     68876  2014-07-06 00:00:00.0               4124     COMPLETE
# 68877     68878  2014-07-08 00:00:00.0               6753     COMPLETE
# 68878     68879  2014-07-09 00:00:00.0                778     COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117     COMPLETE
# 68882     68883  2014-07-23 00:00:00.0               5533     COMPLETE
#
# [30455 rows x 4 columns]

# %%
orders.query('order_status=="COMPLETE" and order_date=="2014-01-01 00:00:00.0"')
# Out:
#        order_id             order_date  order_customer_id order_status
# 25881     25882  2014-01-01 00:00:00.0               4598     COMPLETE
# 25887     25888  2014-01-01 00:00:00.0               6735     COMPLETE
# 25888     25889  2014-01-01 00:00:00.0              10045     COMPLETE
# 25894     25895  2014-01-01 00:00:00.0               1044     COMPLETE
# 25896     25897  2014-01-01 00:00:00.0               6405     COMPLETE
# 25897     25898  2014-01-01 00:00:00.0               3950     COMPLETE
# 25900     25901  2014-01-01 00:00:00.0               3099     COMPLETE
# 25901     25902  2014-01-01 00:00:00.0               6083     COMPLETE
# 25906     25907  2014-01-01 00:00:00.0               3603     COMPLETE
# 25912     25913  2014-01-01 00:00:00.0               9382     COMPLETE
# 25913     25914  2014-01-01 00:00:00.0               9288     COMPLETE
# 25914     25915  2014-01-01 00:00:00.0               2963     COMPLETE
# ...

# %%
orders.columns
# Out:
# Index(['order_id', 'order_date', 'order_customer_id', 'order_status'], dtype='object')

# %%
orders.groupby('order_status','order_month')['order_id'].agg(orders_count='count')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\vipul\Desktop\python\pr-venv\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 'order_month'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1296\3419986624.py in ?()
# ----> 1 orders.groupby('order_status','order_month')['order_id'].agg(orders_count='count')
#
# c:\Users\vipul\Desktop\python\pr-venv\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9156         observed: bool | lib.NoDefault = lib.no_default,
# ...

# %%
orders['order_month']=orders.apply(lambda order: order.order_date[:7],axis=1)

# %%
orders
# Out:
#        order_id             order_date  order_customer_id     order_status  \
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
#       order_month
# 0         2013-07
# 1         2013-07
# ...

# %%
orders.groupby(['order_status','order_month'])['order_id'].agg(orders_count='count').reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 orders.groupby(['order_status','order_month'])['order_id'].agg(orders_count='count').reset_index()
#
# File c:\Users\vipul\Desktop\python\pr-venv\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
print(orders.columns)
# Out:
# Index(['order_id', 'order_date', 'order_customer_id', 'order_status'], dtype='object')

# %%
customers_coloumns=['customer_id',
                    'customer_fname',
                   'customer_lname',
                    'customer_email',
                     'customer_password',
                      'customer_street',
                       'customer_city',
                        'customer_state',
                         'customer_zipcode' ]

# %%
customers = pd.read_csv(r'Python Collection/retail_db/customers/part-00000', names=customers_coloumns)

# %%
customers
orders
# Out:
#        order_id             order_date  order_customer_id     order_status
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
customers.set_index('customer_id')
# Out:
#             customer_fname customer_lname customer_email customer_password  \
# customer_id
# 1                  Richard      Hernandez      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 3                      Ann          Smith      XXXXXXXXX         XXXXXXXXX
# 4                     Mary          Jones      XXXXXXXXX         XXXXXXXXX
# 5                   Robert         Hudson      XXXXXXXXX         XXXXXXXXX
# ...                    ...            ...            ...               ...
# 12431                 Mary           Rios      XXXXXXXXX         XXXXXXXXX
# 12432               Angela          Smith      XXXXXXXXX         XXXXXXXXX
# 12433             Benjamin         Garcia      XXXXXXXXX         XXXXXXXXX
# 12434                 Mary          Mills      XXXXXXXXX         XXXXXXXXX
# 12435                Laura         Horton      XXXXXXXXX         XXXXXXXXX
#
# ...

# %%
customers=customers.set_index('customer_id')

# %%
orders=orders.set_index('order_customer_id')

# %%
customer_orders=customers.join(orders,how='inner')

# %%
customer_orders
# Out:
#             customer_fname customer_lname customer_email customer_password  \
# customer_id
# 1                  Richard      Hernandez      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# ...                    ...            ...            ...               ...
# 12434                 Mary          Mills      XXXXXXXXX         XXXXXXXXX
# 12434                 Mary          Mills      XXXXXXXXX         XXXXXXXXX
# 12434                 Mary          Mills      XXXXXXXXX         XXXXXXXXX
# 12435                Laura         Horton      XXXXXXXXX         XXXXXXXXX
# 12435                Laura         Horton      XXXXXXXXX         XXXXXXXXX
#
# ...

# %%
customer_orders.shape
# Out:
# (68883, 11)

# %%
customer_orders.reset_index().groupby('customer_id')['customer_id'].agg(order_count='count').query('order_count>10')
# Out:
#              order_count
# customer_id
# 174                   12
# 197                   11
# 221                   15
# 335                   11
# 430                   11
# ...                  ...
# 12221                 12
# 12226                 13
# 12284                 15
# 12329                 11
# 12431                 16
#
# [326 rows x 1 columns]

# %%
customer_orders.sort_values('')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17596\1331096562.py in ?()
# ----> 1 customer_orders.sort_values(True)
#
# c:\Users\vipul\Desktop\python\pr-venv\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# c:\Users\vipul\Desktop\python\pr-venv\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
# ...
